# %%
import pandas as pd

# %%
tb = pd.read_csv('https://github.com/escola-de-dados/notebooks-python-pandas/raw/master/mlb.csv')

# %%
tb.head(10)
# Out:
#                NAME TEAM POS    SALARY  START_YEAR  END_YEAR  YEARS
# 0   Clayton Kershaw  LAD  SP  33000000        2014      2020      7
# 1      Zack Greinke  ARI  SP  31876966        2016      2021      6
# 2       David Price  BOS  SP  30000000        2016      2022      7
# 3    Miguel Cabrera  DET  1B  28000000        2014      2023     10
# 4  Justin Verlander  DET  SP  28000000        2013      2019      7
# 5     Jason Heyward  CHC  RF  26055288        2016      2023      8
# 6     Albert Pujols  LAA  1B  26000000        2012      2021     10
# 7   Felix Hernandez  SEA  SP  25857143        2013      2019      7
# 8        Jon Lester  CHC  SP  25000000        2015      2020      6
# 9       CC Sabathia  NYY  SP  25000000        2012      2016      5

# %%
tb.tail(7)
# Out:
#                  NAME TEAM POS  SALARY  START_YEAR  END_YEAR  YEARS
# 861      Rookie Davis  CIN  SP  535000        2017      2017      1
# 862  Stephen Cardullo  COL  1B  535000        2017      2017      1
# 863      Steve Selsky  BOS  RF  535000        2017      2017      1
# 864     Stuart Turner  CIN   C  535000        2017      2017      1
# 865    Vicente Campos  LAA  RP  535000        2017      2017      1
# 866     Wandy Peralta  CIN  RP  535000        2017      2017      1
# 867        Yandy Diaz  CLE  3B  535000        2017      2017      1

# %%
tb.shape
# Out:
# (868, 7)

# %%
tb.dtypes
# Out:
# NAME          object
# TEAM          object
# POS           object
# SALARY         int64
# START_YEAR     int64
# END_YEAR       int64
# YEARS          int64
# dtype: object

# %%
tb.sort_values('SALARY',ascending=False).head()
# Out:
#                NAME TEAM POS    SALARY  START_YEAR  END_YEAR  YEARS
# 0   Clayton Kershaw  LAD  SP  33000000        2014      2020      7
# 1      Zack Greinke  ARI  SP  31876966        2016      2021      6
# 2       David Price  BOS  SP  30000000        2016      2022      7
# 3    Miguel Cabrera  DET  1B  28000000        2014      2023     10
# 4  Justin Verlander  DET  SP  28000000        2013      2019      7

# %%
tb.sort_values(['SALARY','YEARS'],ascending=[False,True]).head()
# Out:
#                NAME TEAM POS    SALARY  START_YEAR  END_YEAR  YEARS
# 0   Clayton Kershaw  LAD  SP  33000000        2014      2020      7
# 1      Zack Greinke  ARI  SP  31876966        2016      2021      6
# 2       David Price  BOS  SP  30000000        2016      2022      7
# 4  Justin Verlander  DET  SP  28000000        2013      2019      7
# 3    Miguel Cabrera  DET  1B  28000000        2014      2023     10

# %%
maior_Salario = tb.sort_values('SALARY', ascending=False)

# %%
maior_Salario.head()
# Out:
#                NAME TEAM POS    SALARY  START_YEAR  END_YEAR  YEARS
# 0   Clayton Kershaw  LAD  SP  33000000        2014      2020      7
# 1      Zack Greinke  ARI  SP  31876966        2016      2021      6
# 2       David Price  BOS  SP  30000000        2016      2022      7
# 3    Miguel Cabrera  DET  1B  28000000        2014      2023     10
# 4  Justin Verlander  DET  SP  28000000        2013      2019      7

# %%
tb[['NAME','TEAM']]
# Out:
#                  NAME TEAM
# 0     Clayton Kershaw  LAD
# 1        Zack Greinke  ARI
# 2         David Price  BOS
# 3      Miguel Cabrera  DET
# 4    Justin Verlander  DET
# ..                ...  ...
# 863      Steve Selsky  BOS
# 864     Stuart Turner  CIN
# 865    Vicente Campos  LAA
# 866     Wandy Peralta  CIN
# 867        Yandy Diaz  CLE
#
# [868 rows x 2 columns]

# %%
tb[['NAME','SALARY']].min()
# Out:
# NAME      A.J. Ellis
# SALARY        535000
# dtype: object

# %%
tb[tb.SALARY>2000000]
# Out:
#                  NAME TEAM POS    SALARY  START_YEAR  END_YEAR  YEARS
# 0     Clayton Kershaw  LAD  SP  33000000        2014      2020      7
# 1        Zack Greinke  ARI  SP  31876966        2016      2021      6
# 2         David Price  BOS  SP  30000000        2016      2022      7
# 3      Miguel Cabrera  DET  1B  28000000        2014      2023     10
# 4    Justin Verlander  DET  SP  28000000        2013      2019      7
# ..                ...  ...  ..       ...         ...       ...    ...
# 387     Carlos Torres  MIL  RP   2175000        2017      2017      1
# 388     Adam Ottavino  COL  RP   2100000        2016      2018      3
# 389   Jeremy Jeffress  TEX  RP   2100000        2017      2017      1
# 390      Matt Belisle  MIN  RP   2050000        2017      2017      1
# 391   Tyler Thornburg  BOS  RP   2050000        2017      2017      1
#
# [392 rows x 7 columns]

# %%
tb[['TEAM','SALARY']].groupby('TEAM').sum().sort_values('SALARY',ascending=False)
# Out:
#          SALARY
# TEAM
# LAD   187989811
# DET   180250600
# TEX   178431396
# SF    176531278
# NYM   176284679
# BOS   174287098
# NYY   170389199
# CHC   170088502
# WSH   162742157
# TOR   162353367
# BAL   161684185
# SEA   155207720
# STL   146630000
# LAA   143965833
# ATL   137339527
# KC    132091916
# HOU   127443900
# CLE   115991166
# MIA   115348302
# CWS   109591167
# COL   101513571
# MIN   100787500
# PIT    94637833
# ARI    90730499
# PHI    87418378
# CIN    82375785
# OAK    70601667
# TB     69982520
# MIL    61020089
# SD     34574400

# %%
tb[['SALARY','YEARS']].plot.bar(x='SALARY',y='YEARS')
# Out:
# <Axes: xlabel='SALARY'>
